# %%
import giskard

# Replace this with your own data & model creation.
df = giskard.demo.titanic_df()
data_preprocessor, clf = giskard.demo.titanic_pipeline()

# Wrap your Pandas DataFrame with Giskard.Dataset (test set, a golden dataset, etc.). Check the dedicated doc page: https://docs.giskard.ai/en/latest/guides/wrap_dataset/index.html
giskard_dataset = giskard.Dataset(
    df=df,
    # A pandas.DataFrame that contains the raw data (before all the pre-processing steps) and the actual ground truth variable (target).
    target="Survived",  # Ground truth variable
    name="Titanic dataset",  # Optional
    cat_columns=['Pclass', 'Sex', "SibSp", "Parch", "Embarked"]
    # Optional, but is a MUST if available. Inferred automatically if not.
)


# Wrap your model with Giskard.Model. Check the dedicated doc page: https://docs.giskard.ai/en/latest/guides/wrap_model/index.html
# you can use any tabular, text or LLM models (PyTorch, HuggingFace, LangChain, etc.),
# for classification, regression & text generation.
def prediction_function(df):
    # The pre-processor can be a pipeline of one-hot encoding, imputer, scaler, etc.
    preprocessed_df = data_preprocessor(df)
    return clf.predict_proba(preprocessed_df)


giskard_model = giskard.Model(
    model=prediction_function,
    # A prediction function that encapsulates all the data pre-processing steps and that could be executed with the dataset used by the scan.
    model_type="classification",  # Either regression, classification or text_generation.
    name="Titanic model",  # Optional
    classification_labels=clf.classes_,  # Their order MUST be identical to the prediction_function's output order
    feature_names=['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'],
    # Default: all columns of your dataset
    # classification_threshold=0.5,  # Default: 0.5
)

# Then apply the scan
results = giskard.scan(giskard_model, giskard_dataset)

# %%
display(results)
# Out:
# 2023-07-24 16:00:47,847 pid:12879 Thread-126245 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,056 pid:12879 Thread-126318 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,099 pid:12879 Thread-126340 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,099 pid:12879 Thread-126344 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,102 pid:12879 Thread-126330 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,102 pid:12879 Thread-126343 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,214 pid:12879 Thread-126373 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,260 pid:12879 Thread-126383 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,518 pid:12879 Thread-126433 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,520 pid:12879 Thread-126437 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,521 pid:12879 Thread-126446 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,535 pid:12879 Thread-126440 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,549 pid:12879 Thread-126450 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,850 pid:12879 Thread-126525 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,851 pid:12879 Thread-126514 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,858 pid:12879 Thread-126522 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,884 pid:12879 Thread-126529 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,887 pid:12879 Thread-126530 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,899 pid:12879 Thread-126544 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,905 pid:12879 Thread-126546 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,975 pid:12879 Thread-126581 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,975 pid:12879 Thread-126580 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,977 pid:12879 Thread-126578 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,977 pid:12879 Thread-126572 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:48,978 pid:12879 Thread-126569 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:49,003 pid:12879 Thread-126587 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:49,202 pid:12879 Thread-126673 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:49,320 pid:12879 Thread-126724 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:49,362 pid:12879 Thread-126737 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:49,366 pid:12879 Thread-126729 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:49,367 pid:12879 Thread-126739 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:49,851 pid:12879 Thread-126835 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:49,919 pid:12879 Thread-126853 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:49,920 pid:12879 Thread-126858 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:49,995 pid:12879 Thread-126877 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:00:49,996 pid:12879 Thread-126885 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16
(track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:02,410 pid:12879 Thread-163811 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:02,410 pid:12879 Thread-163806 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:02,416 pid:12879 Thread-163808 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:02,416 pid:12879 Thread-163801 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:02,419 pid:12879 Thread-163807 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:02,426 pid:12879 Thread-163818 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:02,426 pid:12879 Thread-163819 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:02,464 pid:12879 Thread-163837 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:02,474 pid:12879 Thread-163848 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:02,474 pid:12879 Thread-163845 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# ...
# 2023-07-24 16:02:07,325 pid:12879 Thread-166515 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:07,421 pid:12879 Thread-166562 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:07,422 pid:12879 Thread-166550 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:07,936 pid:12879 Thread-166847 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:07,937 pid:12879 Thread-166854 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:07,938 pid:12879 Thread-166841 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:07,940 pid:12879 Thread-166824 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:07,996 pid:12879 Thread-166875 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:07,997 pid:12879 Thread-166867 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:07,997 pid:12879 Thread-166860 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:07,997 pid:12879 Thread-166871 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:08,176 pid:12879 Thread-166977 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:08,371 pid:12879 Thread-167078 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:08,425 pid:12879 Thread-167098 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:08,429 pid:12879 Thread-167111 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:08,430 pid:12879 Thread-167119 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:08,569 pid:12879 Thread-167152 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:08,569 pid:12879 Thread-167197 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:08,572 pid:12879 Thread-167178 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:08,574 pid:12879 Thread-167183 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:08,574 pid:12879 Thread-167177 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,084 pid:12879 Thread-167470 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,085 pid:12879 Thread-167472 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,086 pid:12879 Thread-167461 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,188 pid:12879 Thread-167525 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,188 pid:12879 Thread-167516 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,188 pid:12879 Thread-167528 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,189 pid:12879 Thread-167523 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,190 pid:12879 Thread-167519 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,281 pid:12879 Thread-167557 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,285 pid:12879 Thread-167577 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,336 pid:12879 Thread-167609 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,478 pid:12879 Thread-167674 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,524 pid:12879 Thread-167709 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,524 pid:12879 Thread-167686 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,527 pid:12879 Thread-167689 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,630 pid:12879 Thread-167761 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,630 pid:12879 Thread-167755 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,805 pid:12879 Thread-167785 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,822 pid:12879 Thread-167807 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,831 pid:12879 Thread-167775 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,831 pid:12879 Thread-167797 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,833 pid:12879 Thread-167809 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,833 pid:12879 Thread-167796 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,958 pid:12879 Thread-167839 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:09,959 pid:12879 Thread-167840 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:13,425 pid:12879 Thread-169570 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:13,444 pid:12879 Thread-169584 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:19,011 pid:12879 Thread-172415 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 16:02:19,959 pid:12879 Thread-172893 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# <!doctype html>
# <html lang="en">
#
# <head>
#     <title>Giskard Scan Results</title>
#     <base target="_blank">
#     <meta charset="utf-8">
#
# <style>pre code.hljs{display:block;overflow-x:auto;padding:1em}code.hljs{padding:3px 5px}
# /*!
#   Theme: GitHub Dark
#   Description: Dark theme as seen on github.com
#   Author: github.com
#   Maintainer: @Hirse
#   Updated: 2021-05-15
#
#   Outdated base version: https://github.com/primer/github-syntax-dark
#   Current colors taken from GitHub's CSS
# */.hljs{background:#0d1117;color:#c9d1d9}.hljs-doctag,.hljs-keyword,.hljs-meta .hljs-keyword,.hljs-template-tag,.hljs-template-variable,.hljs-type,.hljs-variable.language_{color:#ff7b72}.hljs-title,.hljs-title.class_,.hljs-title.class_.inherited__,.hljs-title.function_{color:#d2a8ff}.hljs-attr,.hljs-attribute,.hljs-literal,.hljs-meta,.hljs-number,.hljs-operator,.hljs-selector-attr,.hljs-selector-class,.hljs-selector-id,.hljs-variable{color:#79c0ff}.hljs-meta .hljs-string,.hljs-regexp,.hljs-string{color:#a5d6ff}.hljs-built_in,.hljs-symbol{color:#ffa657}.hljs-code,.hljs-comment,.hljs-formula{color:#8b949e}.hljs-name,.hljs-quote,.hljs-selector-pseudo,.hljs-selector-tag{color:#7ee787}.hljs-subst{color:#c9d1d9}.hljs-section{color:#1f6feb;font-weight:700}.hljs-bullet{color:#f2cc60}.hljs-emphasis{color:#c9d1d9;font-style:italic}.hljs-strong{color:#c9d1d9;font-weight:700}.hljs-addition{background-color:#033a16;color:#aff5b4}.hljs-deletion{background-color:#67060c;color:#ffdcd7}.hljs-copy-wrapper{overflow:hidden;position:relative}.hljs-copy-button:focus,.hljs-copy-wrapper:hover .hljs-copy-button{transform:translateX(0)}.hljs-copy-button{background-color:#2d2b57;background-color:var(--hljs-theme-background);background-image:url('data:image/svg+xml;charset=utf-8,<svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" fill="none" viewBox="0 0 24 24"><path fill="%23fff" fill-rule="evenodd" d="M6 5a1 1 0 0 0-1 1v14a1 1 0 0 0 1 1h12a1 1 0 0 0 1-1V6a1 1 0 0 0-1-1h-2a1 1 0 1 1 0-2h2a3 3 0 0 1 3 3v14a3 3 0 0 1-3 3H6a3 3 0 0 1-3-3V6a3 3 0 0 1 3-3h2a1 1 0 0 1 0 2H6Z" clip-rule="evenodd"/><path fill="%23fff" fill-rule="evenodd" d="M7 3a2 2 0 0 1 2-2h6a2 2 0 0 1 2 2v2a2 2 0 0 1-2 2H9a2 2 0 0 1-2-2V3Zm8 0H9v2h6V3Z" clip-rule="evenodd"/></svg>');background-position:50%;background-repeat:no-repeat;border:1px solid #ffffff22;border-radius:.25rem;color:#fff;height:2rem;position:absolute;right:1em;text-indent:-9999px;top:1em;transition:background-color .2s ease,transform .2s ease-out;width:2rem}.hljs-copy-button:hover{border-color:#ffffff44}.hljs-copy-button:active{border-color:#ffffff66}.hljs-copy-button[data-copied=true]{background-image:none;text-indent:0;width:auto}@media (prefers-reduced-motion){.hljs-copy-button{transition:none}}.hljs-copy-alert{clip:rect(0 0 0 0);-webkit-clip-path:inset(50%);clip-path:inset(50%);height:1px;overflow:hidden;position:absolute;white-space:nowrap;width:1px}
# /*! tailwindcss v3.3.2 | MIT License | https://tailwindcss.com*/*,:after,:before{border:0 solid #e5e7eb;box-sizing:border-box}:after,:before{--tw-content:""}html{-webkit-text-size-adjust:100%;font-feature-settings:normal;font-family:ui-sans-serif,system-ui,-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,Noto Color Emoji;font-variation-settings:normal;line-height:1.5;-moz-tab-size:4;-o-tab-size:4;tab-size:4}body{line-height:inherit;margin:0}hr{border-top-width:1px;color:inherit;height:0}abbr:where([title]){-webkit-text-decoration:underline dotted;text-decoration:underline dotted}h1,h2,h3,h4,h5,h6{font-size:inherit;font-weight:inherit}a{color:inherit;text-decoration:inherit}b,strong{font-weight:bolder}code,kbd,pre,samp{font-family:ui-monospace,SFMono-Regular,Menlo,Monaco,Consolas,Liberation Mono,Courier New,monospace;font-size:1em}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sub{bottom:-.25em}sup{top:-.5em}table{border-collapse:collapse;border-color:inherit;text-indent:0}button,input,optgroup,select,textarea{color:inherit;font-family:inherit;font-size:100%;font-weight:inherit;line-height:inherit;margin:0;padding:0}button,select{text-transform:none}[type=button],[type=reset],[type=submit],button{-webkit-appearance:button;background-color:transparent;background-image:none}:-moz-focusring{outline:auto}:-moz-ui-invalid{box-shadow:none}progress{vertical-align:baseline}::-webkit-inner-spin-button,::-webkit-outer-spin-button{height:auto}[type=search]{-webkit-appearance:textfield;outline-offset:-2px}::-webkit-search-decoration{-webkit-appearance:none}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}summary{display:list-item}blockquote,dd,dl,figure,h1,h2,h3,h4,h5,h6,hr,p,pre{margin:0}fieldset{margin:0}fieldset,legend{padding:0}menu,ol,ul{list-style:none;margin:0;padding:0}textarea{resize:vertical}input::-moz-placeholder,textarea::-moz-placeholder{color:#9ca3af;opacity:1}input::placeholder,textarea::placeholder{color:#9ca3af;opacity:1}[role=button],button{cursor:pointer}:disabled{cursor:default}audio,canvas,embed,iframe,img,object,svg,video{display:block;vertical-align:middle}img,video{height:auto;max-width:100%}[hidden]{display:none}*,:after,:before{--tw-border-spacing-x:0;--tw-border-spacing-y:0;--tw-translate-x:0;--tw-translate-y:0;--tw-rotate:0;--tw-skew-x:0;--tw-skew-y:0;--tw-scale-x:1;--tw-scale-y:1;--tw-pan-x: ;--tw-pan-y: ;--tw-pinch-zoom: ;--tw-scroll-snap-strictness:proximity;--tw-gradient-from-position: ;--tw-gradient-via-position: ;--tw-gradient-to-position: ;--tw-ordinal: ;--tw-slashed-zero: ;--tw-numeric-figure: ;--tw-numeric-spacing: ;--tw-numeric-fraction: ;--tw-ring-inset: ;--tw-ring-offset-width:0px;--tw-ring-offset-color:#fff;--tw-ring-color:rgba(59,130,246,.5);--tw-ring-offset-shadow:0 0 #0000;--tw-ring-shadow:0 0 #0000;--tw-shadow:0 0 #0000;--tw-shadow-colored:0 0 #0000;--tw-blur: ;--tw-brightness: ;--tw-contrast: ;--tw-grayscale: ;--tw-hue-rotate: ;--tw-invert: ;--tw-saturate: ;--tw-sepia: ;--tw-drop-shadow: ;--tw-backdrop-blur: ;--tw-backdrop-brightness: ;--tw-backdrop-contrast: ;--tw-backdrop-grayscale: ;--tw-backdrop-hue-rotate: ;--tw-backdrop-invert: ;--tw-backdrop-opacity: ;--tw-backdrop-saturate: ;--tw-backdrop-sepia: }::backdrop{--tw-border-spacing-x:0;--tw-border-spacing-y:0;--tw-translate-x:0;--tw-translate-y:0;--tw-rotate:0;--tw-skew-x:0;--tw-skew-y:0;--tw-scale-x:1;--tw-scale-y:1;--tw-pan-x: ;--tw-pan-y: ;--tw-pinch-zoom: ;--tw-scroll-snap-strictness:proximity;--tw-gradient-from-position: ;--tw-gradient-via-position: ;--tw-gradient-to-position: ;--tw-ordinal: ;--tw-slashed-zero: ;--tw-numeric-figure: ;--tw-numeric-spacing: ;--tw-numeric-fraction: ;--tw-ring-inset: ;--tw-ring-offset-width:0px;--tw-ring-offset-color:#fff;--tw-ring-color:rgba(59,130,246,.5);--tw-ring-offset-shadow:0 0 #0000;--tw-ring-shadow:0 0 #0000;--tw-shadow:0 0 #0000;--tw-shad ...

# %%
res = results.generate_test_suite().run()
# Out:
# Executed 'Recall on data slice “`Name` contains "mr"”' with arguments {'model': <giskard.models.function.PredictionFunctionModel object at 0x105673d60>, 'dataset': <giskard.datasets.base.Dataset object at 0x105673cd0>, 'slicing_function': <giskard.slicing.slice.QueryBasedSliceFunction object at 0x17c6df760>, 'threshold': 0.6277777777777778}:
#                Test failed
#                Metric: 0.02
#
#
# Executed 'Recall on data slice “`Sex` == "male"”' with arguments {'model': <giskard.models.function.PredictionFunctionModel object at 0x105673d60>, 'dataset': <giskard.datasets.base.Dataset object at 0x105673cd0>, 'slicing_function': <giskard.slicing.slice.QueryBasedSliceFunction object at 0x177f973d0>, 'threshold': 0.6277777777777778}:
#                Test failed
#                Metric: 0.11
#
#
# Executed 'Precision on data slice “`Pclass` == 3”' with arguments {'model': <giskard.models.function.PredictionFunctionModel object at 0x105673d60>, 'dataset': <giskard.datasets.base.Dataset object at 0x105673cd0>, 'slicing_function': <giskard.slicing.slice.QueryBasedSliceFunction object at 0x177f97670>, 'threshold': 0.7156666666666667}:
#                Test failed
#                Metric: 0.48
#
#
# Executed 'Accuracy on data slice “`Name` contains "master"”' with arguments {'model': <giskard.models.function.PredictionFunctionModel object at 0x105673d60>, 'dataset': <giskard.datasets.base.Dataset object at 0x105673cd0>, 'slicing_function': <giskard.slicing.slice.QueryBasedSliceFunction object at 0x17c95f700>, 'threshold': 0.7476457399103139}:
#                Test failed
#                Metric: 0.71
#
#
# Executed 'Recall on data slice “`Parch` == 0”' with arguments {'model': <giskard.models.function.PredictionFunctionModel object at 0x105673d60>, 'dataset': <giskard.datasets.base.Dataset object at 0x105673cd0>, 'slicing_function': <giskard.slicing.slice.QueryBasedSliceFunction object at 0x177f97f70>, 'threshold': 0.6277777777777778}:
#                Test failed
#                Metric: 0.6
#
#
# Executed 'Precision on data slice “`Parch` == 2”' with arguments {'model': <giskard.models.function.PredictionFunctionModel object at 0x105673d60>, 'dataset': <giskard.datasets.base.Dataset object at 0x105673cd0>, 'slicing_function': <giskard.slicing.slice.QueryBasedSliceFunction object at 0x17a1ec190>, 'threshold': 0.7156666666666667}:
#                Test failed
#                Metric: 0.69
#
#
# Executed 'Recall on data slice “`Embarked` == "S"”' with arguments {'model': <giskard.models.function.PredictionFunctionModel object at 0x105673d60>, 'dataset': <giskard.datasets.base.Dataset object at 0x105673cd0>, 'slicing_function': <giskard.slicing.slice.QueryBasedSliceFunction object at 0x17a1ec5e0>, 'threshold': 0.6277777777777778}:
#                Test failed
#                Metric: 0.61
#
#
# Executed 'Accuracy on data slice “`Pclass` == 1”' with arguments {'model': <giskard.models.function.PredictionFunctionModel object at 0x105673d60>, 'dataset': <giskard.datasets.base.Dataset object at 0x105673cd0>, 'slicing_function': <giskard.slicing.slice.QueryBasedSliceFunction object at 0x177f96500>, 'threshold': 0.7476457399103139}:
#                Test failed
#                Metric: 0.73
#
#
# Executed 'Accuracy on data slice “`Name` contains "miss"”' with arguments {'model': <giskard.models.function.PredictionFunctionModel object at 0x105673d60>, 'dataset': <giskard.datasets.base.Dataset object at 0x105673cd0>, 'slicing_function': <giskard.slicing.slice.QueryBasedSliceFunction object at 0x17c974700>, 'threshold': 0.7476457399103139}:
#                Test failed
#                Metric: 0.74
#
#
# 2023-07-24 15:58:28,116 pid:12879 Thread-19128 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:28,120 pid:12879 Thread-19113 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# Executed 'Precision on data slice “`Embarked` == "Q"”' with arguments {'model': <giskard.models.function.PredictionFunctionModel object at 0x105673d60>, 'dataset': <giskard.datasets.base.Dataset object at 0x105673cd0>, 'slicing_function': <giskard.slicing.slice.QueryBasedSliceFunction object at 0x17a1ec760>, 'threshold': 0.7156666666666667}:
#                Test failed
#                Metric: 0.71
#
#
# 2023-07-24 15:58:28,209 pid:12879 Thread-19191 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:28,213 pid:12879 Thread-19205 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,000 pid:12879 Thread-19404 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,046 pid:12879 Thread-19473 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,049 pid:12879 Thread-19477 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,063 pid:12879 Thread-19497 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,163 pid:12879 Thread-19602 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,167 pid:12879 Thread-19607 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,167 pid:12879 Thread-19578 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,169 pid:12879 Thread-19604 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,169 pid:12879 Thread-19603 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,170 pid:12879 Thread-19600 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,253 pid:12879 Thread-19688 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,253 pid:12879 Thread-19686 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,255 pid:12879 Thread-19691 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,256 pid:12879 Thread-19697 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,256 pid:12879 Thread-19682 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,256 pid:12879 Thread-19689 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,279 pid:12879 Thread-19727 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,357 pid:12879 Thread-19813 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,357 pid:12879 Thread-19822 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,357 pid:12879 Thread-19824 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,358 pid:12879 Thread-19827 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,441 pid:12879 Thread-19909 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,487 pid:12879 Thread-19972 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:29,822 pid:12879 Thread-20093 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:30,047 pid:12879 Thread-20202 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:30,048 pid:12879 Thread-20211 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:30,112 pid:12879 Thread-20273 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:30,119 pid:12879 Thread-20279 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:30,162 pid:12879 Thread-20340 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:30,163 pid:12879 Thread-20347 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:30,163 pid:12879 Thread-20349 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:30,233 pid:12879 Thread-20446 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24
(track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# Executed 'Invariance to “Transform to title case”' with arguments {'model': <giskard.models.function.PredictionFunctionModel object at 0x105673d60>, 'dataset': <giskard.datasets.base.Dataset object at 0x105673cd0>, 'transformation_function': <giskard.scanner.robustness.text_transformations.TextTitleCase object at 0x177e3b850>, 'threshold': 0.95, 'output_sensitivity': 0.05}:
#                Test failed
#                Metric: 0.93
#                 - [TestMessageLevel.INFO] 15 rows were perturbed
#
# 2023-07-24 15:58:40,429 pid:12879 Thread-28499 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# Executed 'Overconfidence on data slice “`Name` contains "mr"”' with arguments {'model': <giskard.models.function.PredictionFunctionModel object at 0x105673d60>, 'dataset': <giskard.datasets.base.Dataset object at 0x105673cd0>, 'slicing_function': <giskard.slicing.slice.QueryBasedSliceFunction object at 0x17a1edb40>, 'threshold': 0.428421052631579, 'p_threshold': 0.5}:
#                Test failed
#                Metric: 0.62
#
#
# Executed 'Overconfidence on data slice “`text_length(Name)` < 23.500”' with arguments {'model': <giskard.models.function.PredictionFunctionModel object at 0x105673d60>, 'dataset': <giskard.datasets.base.Dataset object at 0x105673cd0>, 'slicing_function': <giskard.slicing.text_slicer.MetadataSliceFunction object at 0x177e4e320>, 'threshold': 0.428421052631579, 'p_threshold': 0.5}:
#                Test failed
#                Metric: 0.59
#
#                2023-07-24 15:58:40,642 pid:12879 Thread-28650 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
#
# Executed 'Overconfidence on data slice “`Sex` == "male"”' with arguments {'model': <giskard.models.function.PredictionFunctionModel object at 0x105673d60>, 'dataset': <giskard.datasets.base.Dataset object at 0x105673cd0>, 'slicing_function': <giskard.slicing.slice.QueryBasedSliceFunction object at 0x177ce9690>, 'threshold': 0.428421052631579, 'p_threshold': 0.5}:
#                Test failed
#                Metric: 0.53
#
#
# 2023-07-24 15:58:40,723 pid:12879 Thread-28714 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:40,724 pid:12879 Thread-28723 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# Executed 'Overconfidence on data slice “`Fare` < 10.490”' with arguments {'model': <giskard.models.function.PredictionFunctionModel object at 0x105673d60>, 'dataset': <giskard.datasets.base.Dataset object at 0x105673cd0>, 'slicing_function': <giskard.slicing.slice.QueryBasedSliceFunction object at 0x17cb0af80>, 'threshold': 0.428421052631579, 'p_threshold': 0.5}:
#                Test failed
#                Metric: 0.53
#
#
# 2023-07-24 15:58:40,774 pid:12879 Thread-28764 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:40,805 pid:12879 Thread-28799 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:40,806 pid:12879 Thread-28787 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:40,833 pid:12879 Thread-28833 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# Executed 'Overconfidence on data slice “`Age` >= 30.500”' with arguments {'model': <giskard.models.function.PredictionFunctionModel object at 0x105673d60>, 'dataset': <giskard.datasets.base.Dataset object at 0x105673cd0>, 'slicing_function': <giskard.slicing.slice.QueryBasedSliceFunction object at 0x17ca2c1f0>, 'threshold': 0.428421052631579, 'p_threshold': 0.5}:
#                Test failed
#                Metric: 0.5
#
#
# 2023-07-24 15:58:40,869 pid:12879 Thread-28880 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:40,869 pid:12879 Thread-28869 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:40,870 pid:12879 Thread-28874 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:40,870 pid:12879 Thread-28890 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:40,938 pid:12879 Thread-28956 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# Executed 'Overconfidence on data slice “`avg_whitespace(Name)` < 0.120 AND `avg_whitespace(Name)` >= 0.106”' with arguments {'model': <giskard.models.function.PredictionFunctionModel object at 0x105673d60>, 'dataset': <giskard.datasets.base.Dataset object at 0x105673cd0>, 'slicing_function': <giskard.slicing.text_slicer.MetadataSliceFunction object at 0x17cb0b850>, 'threshold': 0.428421052631579, 'p_threshold': 0.5}:
#                Test failed
#                Metric: 0.48
#
#
# 2023-07-24 15:58:40,996 pid:12879 Thread-29012 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:40,997 pid:12879 Thread-29001 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# Executed 'Overconfidence on data slice “`Parch` == 0”' with arguments {'model': <giskard.models.function.PredictionFunctionModel object at 0x105673d60>, 'dataset': <giskard.datasets.base.Dataset object at 0x105673cd0>, 'slicing_function': <giskard.slicing.slice.QueryBasedSliceFunction object at 0x177ebdf90>, 'threshold': 0.428421052631579, 'p_threshold': 0.5}:
#                Test failed
#                Metric: 0.48
#
#
# 2023-07-24 15:58:41,003 pid:12879 Thread-29018 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# Executed 'Overconfidence on data slice “`avg_whitespace(Name)` >= 0.120”' with arguments {'model': <giskard.models.function.PredictionFunctionModel object at 0x105673d60>, 'dataset': <giskard.datasets.base.Dataset object at 0x105673cd0>, 'slicing_function': <giskard.slicing.text_slicer.MetadataSliceFunction object at 0x17cabb160>, 'threshold': 0.428421052631579, 'p_threshold': 0.5}:
#                Test failed
#                Metric: 0.47
#
#
# 2023-07-24 15:58:41,197 pid:12879 Thread-29106 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# Executed 'Overconfidence on data slice “`SibSp` == 0”' with arguments {'model': <giskard.models.function.PredictionFunctionModel object at 0x105673d60>, 'dataset': <giskard.datasets.base.Dataset object at 0x105673cd0>, 'slicing_function': <giskard.slicing.slice.QueryBasedSliceFunction object at 0x177ebcd30>, 'threshold': 0.428421052631579, 'p_threshold': 0.5}:
#                Test failed
#                Metric: 0.44
#
#
# 2023-07-24 15:58:41,198 pid:12879 Thread-29110 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:41,202 pid:12879 Thread-29117 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# Executed 'Overconfidence on data slice “`text_length(Name)` >= 23.500 AND `text_length(Name)` < 29.500”' with arguments {'model': <giskard.models.function.PredictionFunctionModel object at 0x105673d60>, 'dataset': <giskard.datasets.base.Dataset object at 0x105673cd0>, 'slicing_function': <giskard.slicing.text_slicer.MetadataSliceFunction object at 0x177e92380>, 'threshold': 0.428421052631579, 'p_threshold': 0.5}:
#                Test failed
#                Metric: 0.43
#
#
# 2023-07-24 15:58:41,203 pid:12879 Thread-29112 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:41,203 pid:12879 Thread-29105 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:41,203 pid:12879 Thread-29104 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10

# %%
display(res)
# Out:
# 2023-07-24 15:58:41,230 pid:12879 Thread-29130 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:41,230 pid:12879 Thread-29124 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:41,230 pid:12879 Thread-29138 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:41,230 pid:12879 Thread-29132 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# <TestSuiteResult (failed)>
# 2023-07-24 15:58:41,230 pid:12879 Thread-29137 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:41,301 pid:12879 Thread-29215 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:41,308 pid:12879 Thread-29218 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
# 2023-07-24 15:58:41,308 pid:12879 Thread-29220 (track) urllib3.connectionpool WARNING  Connection pool is full, discarding connection: api.mixpanel.com. Connection pool size: 10
